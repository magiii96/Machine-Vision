# %%
import glob
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load Image of Apples

# %%
ColorImage = glob.glob("apples/*.jpg") 
ColorImgs = [] 
for myFile in ColorImage:
    im = plt.imread(myFile)
    #change the range of each channel into [0,1]
    im = im/255
    ColorImgs.append(im)

# %% [markdown]
# Load Mask of Apples

# %%
mask = glob.glob("apples/*.png") 
masks = [] 
for myFile in mask:
    im = plt.imread(myFile) 
    #we only need 1-channel to display mask image
    im = im[:,:,0]
    masks.append(im)

# %% [markdown]
# Generate a d by n training data matrix, where d is the dimension of training data and n is number of data.

# %%
Apple=[]
NonApple=[]
# use these number to calculate the prior of apple. P(apple) = nofapple /(nofapple + nofnonapple)
nofapple=0
nofnonapple=0

for i in range(len(ColorImgs)):
    rows,cols,channel = ColorImgs[i].shape
    for r in range(rows):
        for c in range(cols):
            # If equals to zero means this pxiel is black and it indicate that it belongs to nonapple part.
            if masks[i][r,c]==0.0:
                NonApple.append(ColorImgs[i][r,c,:])
                nofnonapple+=1
            # White pixels indicate locations where the corresponding photo is an apple
            else:
                Apple.append(ColorImgs[i][r,c,:])
                nofapple+=1
                
# change our data to be d*n data martix                
Apple=np.array(Apple).T
NonApple=np.array(NonApple).T

# %% [markdown]
# Helper function for calculate the gaussian distribution.

# %%
#the goal of this routine is to evaluate a Gaussian likelihood
def getGaussProb(x,mean,cov):
    """
    Returns the likelihood that each data point in data belongs to the Gaussian described by gaussMean and 
    gaussCov.
    Keyword arguments:
    data -- d by n matrix of data points. d is the number of dimensions and n is the number of data points.
    gaussMean -- d by 1 vector containing the mean parameter of the Gaussian distribution.
    gaussCov -- d by d matrix containing the covariance parameters of the Gaussian distribution.
    
    Returns: 
    like -- 1 by n vector contianing the likelihood that each data point in data belongs to the Gaussian 
    distribution defined by gaussMean and gaussCov.
    """
    nDim = x.shape[0] 
    mean = np.expand_dims(mean, axis=1)
    prob = np.exp(np.sum(-0.5*((x - mean).T @ np.linalg.pinv(cov)) * (x - mean).T, axis=1))
    prob = prob/((2.0*np.pi)**(nDim/2)*np.linalg.det(cov)**(1/2))
    return prob

# %% [markdown]
# **Calculate likelihood of pixels**
#
# It calculate the likelihood of each pixel by combining all the likelihood of different Gaussian models together using weighted sum.

# %%
def getMixGaussLike(data, mixGaussEst): 
    """
    Calculate the log likelihood for the whole dataset under a mixture of Gaussians model.
    
    Keyword arguments:
    data -- d by n matrix containing data points.
    mixGaussEst -- dict containing the mixture of gaussians parameters.

    Returns: 
    Like -- n by 1 matrix
    
    """
    # initialize ikelihoods                                                                       
    Like = np.zeros((data.shape[1], ))                                                                               
    for i in range(mixGaussEst['k']):
        prob = getGaussProb(data, mixGaussEst['mean'][:,i], mixGaussEst['cov'][:,:,i]) 
        Like += mixGaussEst['weight'][i] * prob  
    return  Like

# %% [markdown]
# **Method for training a mixture of Gaussian model**

# %%
def fitMixGauss(data, k):
    """
    Estimate a k MoG model that would fit the data. Incremently plots the outcome.
               
    
    Keyword arguments:
    data -- d by n matrix containing data points.
    k -- scalar representing the number of gaussians to use in the MoG model.
    
    Returns: 
    mixGaussEst -- dict containing the estimated MoG parameters.
    
    """
    
    #     MAIN E-M ROUTINE  
    #     In the E-M algorithm, we calculate a complete posterior distribution over                                  
    #     the (nData) hidden variables in the E-Step.  
    #     In the M-Step, we update the parameters of the Gaussians (mean, cov, w).   
    nDims, nData = data.shape
    postHidden = np.zeros(shape=(k, nData))

    # we will initialize the values to random values
    mixGaussEst = dict()
    mixGaussEst['d'] = nDims
    mixGaussEst['k'] = k
    mixGaussEst['weight'] = (1 / k) * np.ones(shape=(k))
    mixGaussEst['mean'] = 2 * np.random.randn(nDims, k)
    mixGaussEst['cov'] = np.zeros(shape=(nDims, nDims, k))
    
    for cGauss in range(k):
        mixGaussEst['cov'][:, :, cGauss] = 2.5 + 1.5 * np.random.uniform() * np.eye(nDims)
    
    nIter = 100
    Like = getMixGaussLike(data, mixGaussEst)
    likesum = Like.sum() 
    print('Likelihood Iter 0 : {:4.3f}\n'.format(likesum))
    
    for cIter in range(nIter):
        #print('%d-th iteration'%(cIter))

        # ===================== =====================
        # Expectation step
        # ===================== =====================
        curCov = mixGaussEst['cov']                                                                                  
        curWeight = mixGaussEst['weight']                                                                            
        curMean = mixGaussEst['mean'] 
        
        #calculate posterior probability that
        #this data point came from each of the Gaussians
        for i in range(k):
            postHidden[i] = curWeight[i]*getGaussProb(data,curMean[:,i],curCov[:,:,i])
        #postHidden is k by n
        postHidden = postHidden / np.sum(postHidden, axis=0)
        
    
        # ===================== =====================
        # Maximization Step
        # ===================== =====================
        # for each constituent Gaussian
        for cGauss in range(k):
            # Update weighting parameters mixGauss.weight based on the total
            # posterior probability associated with each Gaussian.
            curWeight[cGauss] = postHidden[cGauss,:].sum()/postHidden.sum()
            

            # Update mean parameters mixGauss.mean by weighted average
            # where weights are given by posterior probability associated with Gaussian.  
            curMean[:,cGauss] = (postHidden[cGauss,:].reshape(1,nData) @ data.T)/ postHidden[cGauss,:].sum()

            # Update covarance parameter based on weighted average of
            # square distance from update mean, where weights are given by
            # posterior probability associated with Gaussian
            meand = np.expand_dims(curMean[:,cGauss], axis=1)
            rikcov = postHidden[cGauss]*(data - meand) @ (data - meand).T
            curCov[:,:,cGauss] = rikcov / postHidden[cGauss,:].sum() 
            # calculate the log likelihood
        like = getMixGaussLike(data, mixGaussEst)
        likesum = like.sum()
        print('Likelihood After Iter {} : {:4.3f}\n'.format(cIter, likesum))
            
    return mixGaussEst

# %% [markdown]
# **Train a mixture of Gaussians model for apples and non-apples pixels**

# %%
# %time
#define number of components to estimate
Hiddenv = 4

#fit mixture of Gaussians 
appleMixGaussEst = fitMixGauss(Apple,Hiddenv);
nonAppleMixGaussEst = fitMixGauss(NonApple,Hiddenv);
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# Likelihood Iter 0 : 79.636
#
# Likelihood After Iter 0 : 1082010.562
#
# Likelihood After Iter 1 : 1082567.031
#
# Likelihood After Iter 2 : 1129219.827
#
# Likelihood After Iter 3 : 3936647.193
#
# Likelihood After Iter 4 : 7413380.948
#
# Likelihood After Iter 5 : 7821729.906
#
# Likelihood After Iter 6 : 7661625.972
#
# Likelihood After Iter 7 : 7418906.834
#
# Likelihood After Iter 8 : 7262091.661
#
# Likelihood After Iter 9 : 7238884.865
#
# Likelihood After Iter 10 : 7445155.546
#
# Likelihood After Iter 11 : 7812029.419
#
# Likelihood After Iter 12 : 8191544.490
#
# Likelihood After Iter 13 : 8499530.742
#
# Likelihood After Iter 14 : 8742351.718
#
# Likelihood After Iter 15 : 8952681.035
#
# Likelihood After Iter 16 : 9146532.443
#
# Likelihood After Iter 17 : 9329040.045
#
# Likelihood After Iter 18 : 9500902.157
#
# Likelihood After Iter 19 : 9662697.901
#
# Likelihood After Iter 20 : 9813353.059
#
# Likelihood After Iter 21 : 9943185.418
#
# Likelihood After Iter 22 : 10036754.367
#
# Likelihood After Iter 23 : 10086644.037
#
# Likelihood After Iter 24 : 10113502.309
#
# Likelihood After Iter 25 : 10136603.732
#
# Likelihood After Iter 26 : 10154852.250
#
# Likelihood After Iter 27 : 10167381.404
#
# Likelihood After Iter 28 : 10174949.288
#
# Likelihood After Iter 29 : 10178619.585
#
# Likelihood After Iter 30 : 10179248.145
#
# Likelihood After Iter 31 : 10177491.552
#
# Likelihood After Iter 32 : 10173914.076
#
# Likelihood After Iter 33 : 10168999.216
#
# Likelihood After Iter 34 : 10163131.206
#
# Likelihood After Iter 35 : 10156596.754
#
# Likelihood After Iter 36 : 10149603.689
#
# Likelihood After Iter 37 : 10142302.274
#
# Likelihood After Iter 38 : 10134802.341
#
# Likelihood After Iter 39 : 10127185.306
#
# Likelihood After Iter 40 : 10119512.210
#
# Likelihood After Iter 41 : 10111829.097
#
# Likelihood After Iter 42 : 10104170.692
#
# Likelihood After Iter 43 : 10096563.009
#
# Likelihood After Iter 44 : 10089025.263
#
# Likelihood After Iter 45 : 10081571.328
#
# Likelihood After Iter 46 : 10074210.871
#
# Likelihood After Iter 47 : 10066950.253
#
# Likelihood After Iter 48 : 10059793.256
#
# Likelihood After Iter 49 : 10052741.674
#
# Likelihood After Iter 50 : 10045795.790
#
# Likelihood After Iter 51 : 10038954.771
#
# Likelihood After Iter 52 : 10032216.986
#
# Likelihood After Iter 53 : 10025580.266
#
# Likelihood After Iter 54 : 10019042.115
#
# Likelihood After Iter 55 : 10012599.882
#
# Likelihood After Iter 56 : 10006250.895
#
# Likelihood After Iter 57 : 9999992.567
#
# Likelihood After Iter 58 : 9993822.483
#
# Likelihood After Iter 59 : 9987738.461
#
# Likelihood After Iter 60 : 9981738.603
#
# Likelihood After Iter 61 : 9975821.324
#
# Likelihood After Iter 62 : 9969985.374
#
# Likelihood After Iter 63 : 9964229.852
#
# Likelihood After Iter 64 : 9958554.204
#
# Likelihood After Iter 65 : 9952958.220
#
# Likelihood After Iter 66 : 9947442.022
#
# Likelihood After Iter 67 : 9942006.046
#
# Likelihood After Iter 68 : 9936651.020
#
# Likelihood After Iter 69 : 9931377.937
#
# Likelihood After Iter 70 : 9926188.030
#
# Likelihood After Iter 71 : 9921082.732
#
# Likelihood After Iter 72 : 9916063.649
#
# Likelihood After Iter 73 : 9911132.519
#
# Likelihood After Iter 74 : 9906291.178
#
# Likelihood After Iter 75 : 9901541.524
#
# Likelihood After Iter 76 : 9896885.478
#
# Likelihood After Iter 77 : 9892324.950
#
# Likelihood After Iter 78 : 9887861.803
#
# Likelihood After Iter 79 : 9883497.823
#
# Likelihood After Iter 80 : 9879234.687
#
# Likelihood After Iter 81 : 9875073.935
#
# Likelihood After Iter 82 : 9871016.948
#
# Likelihood After Iter 83 : 9867064.926
#
# Likelihood After Iter 84 : 9863218.868
#
# Likelihood After Iter 85 : 9859479.560
#
# Likelihood After Iter 86 : 9855847.563
#
# Likelihood After Iter 87 : 9852323.206
#
# Likelihood After Iter 88 : 9848906.584
#
# Likelihood After Iter 89 : 9845597.552
#
# Likelihood After Iter 90 : 9842395.734
#
# Likelihood After Iter 91 : 9839300.521
#
# Likelihood After Iter 92 : 9836311.084
#
# Likelihood After Iter 93 : 9833426.379
#
# Likelihood After Iter 94 : 9830645.161
#
# Likelihood After Iter 95 : 9827965.997
#
# Likelihood After Iter 96 : 9825387.277
#
# Likelihood After Iter 97 : 9822907.231
#
# Likelihood After Iter 98 : 9820523.943
#
# Likelihood After Iter 99 : 9818235.369
#
# Likelihood Iter 0 : 2029.645
#
# Likelihood After Iter 0 : 1857286.573
#
# Likelihood After Iter 1 : 1970777.447
#
# Likelihood After Iter 2 : 2330191.682
#
# Likelihood After Iter 3 : 2723252.181
#
# Likelihood After Iter 4 : 3034387.330
#
# Likelihood After Iter 5 : 3475450.523
#
# Likelihood After Iter 6 : 4338967.149
#
# Likelihood After Iter 7 : 5227463.133
#
# Likelihood After Iter 8 : 5744908.794
#
# Likelihood After Iter 9 : 6193574.359
#
# Likelihood After Iter 10 : 6951896.553
#
# Likelihood After Iter 11 : 8673041.475
#
# Likelihood After Iter 12 : 12409022.989
#
# Likelihood After Iter 13 : 16985226.461
#
# Likelihood After Iter 14 : 19180313.181
#
# Likelihood After Iter 15 : 19733211.329
#
# Likelihood After Iter 16 : 19835488.593
#
# Likelihood After Iter 17 : 19817331.922
#
# Likelihood After Iter 18 : 19760091.452
#
# Likelihood After Iter 19 : 19687676.517
#
# Likelihood After Iter 20 : 19607343.753
#
# Likelihood After Iter 21 : 19521096.916
#
# Likelihood After Iter 22 : 19429603.281
#
# Likelihood After Iter 23 : 19337054.545
#
# Likelihood After Iter 24 : 19310479.209
#
# Likelihood After Iter 25 : 19302055.220
#
# Likelihood After Iter 26 : 19308830.230
#
# Likelihood After Iter 27 : 19329871.851
#
# Likelihood After Iter 28 : 19362743.942
#
# Likelihood After Iter 29 : 19409595.804
#
# Likelihood After Iter 30 : 19476855.894
#
# Likelihood After Iter 31 : 19581845.220
#
# Likelihood After Iter 32 : 19735625.565
#
# Likelihood After Iter 33 : 19937039.792
#
# Likelihood After Iter 34 : 20178517.957
#
# Likelihood After Iter 35 : 20447682.426
#
# Likelihood After Iter 36 : 20734332.943
#
# Likelihood After Iter 37 : 21030905.199
#
# Likelihood After Iter 38 : 21331339.193
#
# Likelihood After Iter 39 : 21631485.067
#
# Likelihood After Iter 40 : 21928548.512
#
# Likelihood After Iter 41 : 22220625.112
#
# Likelihood After Iter 42 : 22506523.561
#
# Likelihood After Iter 43 : 22785629.468
#
# Likelihood After Iter 44 : 23057774.903
#
# Likelihood After Iter 45 : 23323133.462
#
# Likelihood After Iter 46 : 23582137.120
#
# Likelihood After Iter 47 : 23835414.914
#
# Likelihood After Iter 48 : 24083751.979
#
# Likelihood After Iter 49 : 24328065.732
#
# Likelihood After Iter 50 : 24569396.140
#
# Likelihood After Iter 51 : 24808908.004
#
# Likelihood After Iter 52 : 25047904.278
#
# Likelihood After Iter 53 : 25287850.667
#
# Likelihood After Iter 54 : 25530412.894
#
# Likelihood After Iter 55 : 25777509.413
#
# Likelihood After Iter 56 : 26031384.136
#
# Likelihood After Iter 57 : 26294706.060
#
# Likelihood After Iter 58 : 26570706.163
#
# Likelihood After Iter 59 : 26863366.897
#
# Likelihood After Iter 60 : 27177687.119
#
# Likelihood After Iter 61 : 27520056.368
#
# Likelihood After Iter 62 : 27898788.781
#
# Likelihood After Iter 63 : 28324889.944
#
# Likelihood After Iter 64 : 28813159.240
#
# Likelihood After Iter 65 : 29383757.424
#
# Likelihood After Iter 66 : 30064360.738
#
# Likelihood After Iter 67 : 30892879.599
#
# Likelihood After Iter 68 : 31920210.608
#
# Likelihood After Iter 69 : 33211288.572
#
# Likelihood After Iter 70 : 34841085.395
#
# Likelihood After Iter 71 : 36883024.561
#
# Likelihood After Iter 72 : 39395729.855
#
# Likelihood After Iter 73 : 42426587.236
#
# Likelihood After Iter 74 : 46047688.126
#
# Likelihood After Iter 75 : 50395991.330
#
# Likelihood After Iter 76 : 55679081.842
#
# Likelihood After Iter 77 : 62192468.415
#
# Likelihood After Iter 78 : 70292020.767
#
# Likelihood After Iter 79 : 80115369.747
#
# Likelihood After Iter 80 : 91551217.647
#
# Likelihood After Iter 81 : 104441094.279
#
# Likelihood After Iter 82 : 118275745.772
#
# Likelihood After Iter 83 : 132184878.576
#
# Likelihood After Iter 84 : 145653687.063
#
# Likelihood After Iter 85 : 157949485.655
#
# Likelihood After Iter 86 : 168532814.774
#
# Likelihood After Iter 87 : 177267874.086
#
# Likelihood After Iter 88 : 184268809.507
#
# Likelihood After Iter 89 : 189786668.463
#
# Likelihood After Iter 90 : 194116119.941
#
# Likelihood After Iter 91 : 197530679.342
#
# Likelihood After Iter 92 : 200252039.605
#
# Likelihood After Iter 93 : 202448684.387
#
# Likelihood After Iter 94 : 204245209.155
#
# Likelihood After Iter 95 : 205732805.066
#
# Likelihood After Iter 96 : 206978187.969
#
# Likelihood After Iter 97 : 208030518.620
#
# Likelihood After Iter 98 : 208926499.030
# Likelihood After Iter 99 : 209694002.233

# %% [markdown]
# An interesting fact is that our data model does not converge with give iteration.

# %% [markdown]
# Guess:
# 1. The more iteration we loop we will get more accurate data.
# 2. The hidden variable which is number of gaussian in our model will also affect the performance of    our           training example.
# 3. Influence by large covariance.

# %% [markdown]
# Calculate each pixel’s posterior probability of being “apple.”

# %%
def CalculatePosterior(Imgs,priorApple):
    """
    Returns:
    A list of posterior corresponding to each picture of apple.
    """
    # since we calculate the posterior of multiple images at the same time, 
    #we need to create a arry to store them all.
    posteriorApple = []
    for i in range(len(Imgs)):
        img = Imgs[i]
        rows, cols, cha = img.shape
        img = np.double(img)
        #change the img into n*d dataset
        img = np.reshape(img, [rows*cols,cha])
        img = img.T
        #to keep consistent we use d*n matrix to calculate the likelihood
        likApple = getMixGaussLike(img,appleMixGaussEst)
        liknonApple = getMixGaussLike(img,nonAppleMixGaussEst)
        posterior = (likApple*priorApple)/(likApple*priorApple+liknonApple*(1 - priorApple))
        posterior = np.reshape(posterior, (rows, cols))
        posteriorApple += [posterior]
    return posteriorApple

# %%
def calculatePrior(napple,nnonapple):
    """
    Returns:
    The prior of our apples.
    """
    priorApple = napple/(napple + nnonapple)
    return priorApple

# %%
def calculateBinary(images, posteriorApples):
    """
    Returns: 
    The binary result of our images with given posterior.
    """
    binaryApples = []
    for i in range(len(images)):
        rows, cols, cha = images[i].shape
        posteriorApple = posteriorApples[i]  
        binaryApple = np.zeros((rows,cols))
        for r in range(rows):
            for c in range(cols):
                if posteriorApple[r][c] >= 0.5:
                    binaryApple[r][c] = 1
                if posteriorApple[r][c] < 0.5:
                    binaryApple[r][c] = 0
        binaryApples += [binaryApple]
    return binaryApples

# %%
def CalculateRoc(targets, outputs): 
    """
    Using Roc curve to quantify and report our results of test images with a ground-truth mask.
    True Positives (TP)
    True Negatives (TN)
    False Positives (FP)
    False Negatives (FN)
    True Positive Rate (TPR)
    False Positive Rate (FPR)
    
    From the http://people.cs.bris.ac.uk/~flach/papers/ROCanalysis.pdf we know, 
    we often interested the relation between TPR and FPR
    TPR = TP/(TP+FN)
    FPR = FP/(FP+TN)

    Returns: 
    The FPR,TPR which is used for plot our ROC curve.
    
    """
    r,c = targets.shape
    nthreshold = 500
    threshold =  np.linspace(0,1,nthreshold)
    
    TP = np.zeros(nthreshold)
    FP = np.zeros(nthreshold)
    TPR = np.zeros(nthreshold)
    FPR = np.zeros(nthreshold)
   
    for i in range(nthreshold):
        temp = outputs > threshold[i]
        
        TP = (targets * temp).sum()
        FP = temp.sum() - TP
        
        TPR[i] = TP/targets.sum()
        FPR[i] = FP/(r*c - targets.sum())
        
    #This method need lots of memory and time to compute, instead we find anohter efficient way.
    #for i in range(nthreshold): 
        #for r in range(rows):
            #for c in range(cols):
                #if (targets[r][c] == 1) && (outputs[r][c] == 1):
                   # TP[i] += 1
                #else if (targets[r][c] == 1) && (outputs[r][c] == 0):
                    #FP[i] += 1
                #else if (targets[r][c] == 0) && (outputs[r][c] == 1):
                    #FN[i] += 1 
                #else if (targets[r][c] == 0) && (outputs[r][c] == 0):
                    #TN[i] += 1
    #TPR = TP/(TP+FN)
    #FPR = FP/(FP+TN)
    
    
    return FPR,TPR

# %%
# get the prior of apple
priorApple = calculatePrior(nofapple,nofnonapple)
# get the posterior of apple 
posteriorApple = CalculatePosterior(ColorImgs,priorApple)
#get the binary result of apple
binaryApples = calculateBinary(ColorImgs,posteriorApple)

# %%
for i in range(len(posteriorApple)):
    # Set up plots
    f, (ax1, ax2, ax3, ax4) = plt.subplots(1,4)
    # show the image
    ax1.imshow(ColorImgs[i])
    ax1.set_title('image')
    # Show the ground truth mask
    ax2.imshow(masks[i])
    ax2.set_title('Ground Truth')
    # Show our prediction
    ax3.imshow(posteriorApple[i])
    ax3.set_title('Posterior')
    # Show binary result
    ax4.imshow(binaryApples[i])
    ax4.set_title('binary ')
    # show roc curve
    #get roc curve 
    FPR,TPR = CalculateRoc(masks[i],posteriorApple[i])
    f, (ax5) = plt.subplots()
    ax5.set_title('Roc curve of image ')
    plt.plot(FPR,TPR)
    ax5.set_xlabel('FP Rate')
    ax5.set_ylabel('TP Rate')

# %% [markdown]
# Load test images of apples

# %%
testColorImage = glob.glob("testApples/*.jpg") 
testColorImages = [] 
for myFile in testColorImage:     
    im = plt.imread(myFile)
    #change the range of each pixel into [0,1]
    im = im/255
    testColorImages.append(im)

# %% [markdown]
# Load test mask image of apples

# %%
testMask = glob.glob("testapples/*.png") 
testMasks = [] 
for myFile in testMask:
    im = plt.imread(myFile) 
    #we only need 1-channel to display mask image
    im = im[:,:,0] 
    testMasks.append(im)

# %% [markdown]
# Using the prior obtained from training data and calculate the posteriror and binary classification.

# %%
# get the prior of test apple
priorApple = calculatePrior(nofapple,nofnonapple)
#get the posterior of test apple 
posteriorApple2 = CalculatePosterior(testColorImages,priorApple)
#get the binary result of test apple
binaryApples2 = calculateBinary(testColorImages,posteriorApple2)

# %% [markdown]
# Plot each figure correspoding to the test data.

# %%
for i in range(len(posteriorApple2)):
    # Set up plots
    f, (ax1, ax2, ax3, ax4) = plt.subplots(1,4)
    # show the image
    ax1.imshow(testColorImages[i])
    ax1.set_title('image')
    # Show the ground truth mask
    ax2.imshow(testMasks[i])
    ax2.set_title('Ground Truth')
    # Show our prediction
    ax3.imshow(posteriorApple2[i])
    ax3.set_title('Posterior')
    # Show binary result
    ax4.imshow(binaryApples2[i])
    ax4.set_title('binary ')
    # show roc curve
  
    FPR,TPR = CalculateRoc(testMasks[i],posteriorApple2[i])
    f, (ax5) = plt.subplots()
    ax5.set_title('Roc curve of image ')
    plt.plot(FPR,TPR)
    ax5.set_xlabel('FP Rate')
    ax5.set_ylabel('TP Rate')

# %% [markdown]
# Load validate data, more apples data to verify our model.

# %%
ColorImage = glob.glob("moreApples/*.jpg") 
moreColorImages = []
for myFile in ColorImage:     
    im = plt.imread(myFile)
    #change the range of each channel into [0,1]
    im = im/255
    moreColorImages.append(im)

# %% [markdown]
# Load ground truth for our validata data. Creating those pictures by using photoshop.

# %%
MaskImage = glob.glob("moreApples/*.png") 
moreMasks = [] 
for myFile in MaskImage:
    im = plt.imread(myFile) 
    #we only need 1-channel to display mask image
    im = im[:,:,0]
    moreMasks.append(im)

# %% [markdown]
# Using the prior obtained from training data and calculate the posteriror and binary classification.

# %%
# get the prior of apple
priorApple = calculatePrior(nofapple,nofnonapple)
# get the posterior of validate apple data
posteriorApple3 = CalculatePosterior(moreColorImages,priorApple)
#get the binary result of validate apple data
binaryApples3 = calculateBinary(moreColorImages,posteriorApple3)

# %% [markdown]
# Plot each figure correspoding to the validate data.

# %%
for i in range(len(posteriorApple3)):
    # Set up plots
    f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
    # show the image
    ax1.imshow(moreColorImages[i])
    ax1.set_title('image')
    # Show the ground truth mask
    ax2.imshow(moreMasks[i])
    ax2.set_title('Ground Truth')
    # Show our prediction
    ax3.imshow(posteriorApple3[i])
    ax3.set_title('Posterior')
    # Show binary result
    ax4.imshow(binaryApples3[i])
    ax4.set_title('binary result')
    # show roc curve
    FPR,TPR = CalculateRoc(moreMasks[i],posteriorApple3[i])
    f, (ax5) = plt.subplots()
    plt.plot(FPR,TPR)
    ax5.set_title('Roc curve of image ')
    ax5.set_xlabel('FP Rate')
    ax5.set_ylabel('TP Rate')

# %% [markdown]
# **Why we use three separate sets of files**

# %% [markdown]
# Training Set: this data set is used to adjust the weights of model.
# A training dataset is a dataset of examples used for learning, that is to fit the parameters of our model.

# %% [markdown]
# Test Set: A test set is used only to assess the performance of our model.
# A test dataset is a dataset that is independent of the training dataset, but that follows the same probability distribution as the training dataset.

# %% [markdown]
# Validation set: A validation dataset is used to tune the hyperparameters(ie. hidden variable)of our classification model.We can use validation dataset to avoid overfitting.
# This data can provide an unbiased evaluation of a model fit on the training dataset while tuning model hyperparameters.
# We can use validation set to verify the accuracy of our model but indirectly.
